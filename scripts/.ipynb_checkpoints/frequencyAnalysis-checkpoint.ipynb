# %%
# install packages
# !pip install librosa
# !pip install pywt
# !pip install matplotlib
# !pip install noisereduce
# Out:
# Requirement already satisfied: librosa in /Users/dpr12/anaconda3/lib/python3.11/site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from pooch>=1.1->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.6.2)
# ERROR: Could not find a version that satisfies the requirement pywt (from versions: none)
# ERROR: No matching distribution found for pywt
# Requirement already satisfied: matplotlib in /Users/dpr12/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: noisereduce in /Users/dpr12/anaconda3/lib/python3.11/site-packages (3.0.2)
# Requirement already satisfied: scipy in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from noisereduce) (1.11.1)
# Requirement already satisfied: matplotlib in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from noisereduce) (3.7.2)
# Requirement already satisfied: librosa in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from noisereduce) (0.10.2.post1)
# Requirement already satisfied: numpy in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from noisereduce) (1.24.3)
# Requirement already satisfied: tqdm in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from noisereduce) (4.65.0)
# Requirement already satisfied: audioread>=2.1.9 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (0.2)
# Requirement already satisfied: msgpack>=1.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from librosa->noisereduce) (1.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib->noisereduce) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib->noisereduce) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib->noisereduce) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib->noisereduce) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib->noisereduce) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib->noisereduce) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib->noisereduce) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa->noisereduce) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from pooch>=1.1->librosa->noisereduce) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from pooch>=1.1->librosa->noisereduce) (2.31.0)
# Requirement already satisfied: six>=1.5 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa->noisereduce) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa->noisereduce) (1.15.1)
# Requirement already satisfied: pycparser in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa->noisereduce) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa->noisereduce) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa->noisereduce) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa->noisereduce) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dpr12/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa->noisereduce) (2024.6.2)

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal
import noisereduce as nr
import pywt

# %%
def get_high_pass_filter(cutoff_freq, sr):
    nyquist = 0.5 * sr
    normal_cutoff = cutoff_freq / nyquist
    return scipy.signal.butter(1, normal_cutoff, btype='high', analog=False)

def band_stop_filter(y, sr, lowcut, highcut, order=2):
    nyquist = 0.5 * sr
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = scipy.signal.butter(order, [low, high], btype='bandstop')
    y_filtered = scipy.signal.filtfilt(b, a, y)
    return y_filtered

def reduce_noise(y, sr, noise_sample, n_fft=2048, hop_length=512, n_std_thresh=1.5):
    noise_stft = librosa.stft(noise_sample, n_fft=n_fft, hop_length=hop_length)
    noise_stft_db = librosa.amplitude_to_db(np.abs(noise_stft), ref=np.max)
    
    mean_freq_noise = np.mean(noise_stft_db, axis=1)
    std_freq_noise = np.std(noise_stft_db, axis=1)
    
    audio_stft = librosa.stft(y, n_fft=n_fft, hop_length=hop_length)
    audio_stft_db = librosa.amplitude_to_db(np.abs(audio_stft), ref=np.max)
    
    thresh = mean_freq_noise + n_std_thresh * std_freq_noise
    mask = audio_stft_db > thresh[:, np.newaxis]
    audio_stft_db_masked = np.where(mask, audio_stft_db, thresh[:, np.newaxis])
    
    audio_stft_db_masked_lin = librosa.db_to_amplitude(audio_stft_db_masked)
    
    y_denoised = librosa.istft(audio_stft_db_masked_lin, hop_length=hop_length)
    
    return y_denoised

# %%
# target audio file
flight_train_path = '../audios/Barn Owl Nestling\'s Adorable Flight Training Session!.mp3'
y_ft, sr_ft = librosa.load(flight_train_path)

y_ft = nr.reduce_noise(y=y_ft, sr=sr_ft)

# ft_noise_start = 2.1
# ft_noise_end = 2.9

# ft_noise_sample = y_ft[int(ft_noise_start * sr_ft):int(ft_noise_end * sr_ft)]
# y_ft_denoised_filtered = reduce_noise(y_ft, sr_ft, ft_noise_sample)
# y_ft = band_stop_filter(y_ft, sr_ft, lowcut=495, highcut=505)

# %%
def produce_spectrogram(y, sr, cutoff_freq, method='stft', amplitude_t=-40, dur=20):
    b, a = get_high_pass_filter(cutoff_freq, sr)
    y_filtered = scipy.signal.filtfilt(b, a, y)
#     y_filtered = y
    if dur != -1:
        y_filtered = y_filtered[:int(dur * sr)]
    if method == 'stft':
        D_filtered = librosa.stft(y_filtered)
        S_db_filtered = librosa.amplitude_to_db(np.abs(D_filtered), ref=np.max)
        print(f"Shape of D_filtered: {D_filtered.shape}")
        print(f"Shape of S_db_filtered: {S_db_filtered.shape}")

        plt.figure(figsize=(12, 8))
        librosa.display.specshow(S_db_filtered, sr=sr, x_axis='time', y_axis='log')

        plt.ylim(512, sr // 2)

        plt.colorbar(format='%+2.0f dB')
        plt.title(f'Spectrogram (Frequency vs. Time) with High-Pass Filter at {cutoff_freq}Hz')
        plt.xlabel('Time (s)')
        plt.ylabel('Frequency (Hz)')
        plt.clim(vmin=amplitude_t)  # Set the minimum amplitude to display
        plt.show()

        # max amplitude
        frequencies = librosa.fft_frequencies(sr=sr, n_fft=D_filtered.shape[0])
        times = librosa.frames_to_time(np.arange(S_db_filtered.shape[1]), sr=sr, hop_length=512, n_fft=2048)
        peak_frequencies = frequencies[np.clip(np.argmax(S_db_filtered, axis=0), 0, len(frequencies) - 1)]

        plt.figure(figsize=(12, 8))
        plt.plot(times, peak_frequencies, label='Peak Frequency')
        plt.ylim(512, sr // 2)
        plt.xlabel('Time (s)')
        plt.ylabel('Frequency (Hz)')
        plt.title(f'Peak Frequency Over Time for First {dur} Seconds')
        plt.legend()
        plt.show()
    if method == 'wavelet':
        scales = np.arange(1, 64)
        
        coef, freq = pywt.cwt(y_filtered, scales, 'morl', sampling_period=1/sr)
        
        plt.figure(figsize=(12, 8))
        plt.imshow(np.abs(coef), extent=[0, dur, scales[-1], scales[0]], cmap='viridis', aspect='auto',
                   vmax=np.abs(coef).max(), vmin=-np.abs(coef).max())
        plt.colorbar(label='Magnitude')
        plt.title('Wavelet Transform (CWT) of the Audio Signal')
        plt.xlabel('Time (s)')
        plt.ylabel('Scale')
        plt.yscale('log')
        plt.ylim(scales[-1], scales[0])
        plt.show()
        
        peak_frequencies = freq[np.argmax(np.abs(coef), axis=0)]
        times = np.linspace(0, dur, len(peak_frequencies))

        plt.figure(figsize=(12, 8))
        plt.plot(times, peak_frequencies, label='Peak Frequency')
        plt.ylim(512, 10000)
        plt.xlabel('Time (s)')
        plt.ylabel('Frequency (Hz)')
        plt.title('Peak Frequency Over Time for First 20 Seconds')
        plt.legend()
        plt.show()

# %%
def filter_response_plots(y, sr, freq):
    b, a = get_high_pass_filter(freq, sr_ft)
    w, h = scipy.signal.freqz(b, a)

    plt.figure(figsize=(12, 8))

    plt.subplot(2, 1, 1)
    plt.plot(0.5 * sr * w / np.pi, np.abs(h), 'b')
    plt.title('High-Pass Filter Frequency Response - Gain')
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Gain')
    plt.grid()

    plt.subplot(2, 1, 2)
    plt.plot(0.5 * sr * w / np.pi, np.angle(h), 'b')
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Phase [radians]')
    plt.grid()

    plt.tight_layout()
    plt.show()
    
    plt.figure(figsize=(12, 8))

    plt.subplot(2, 1, 1)
    magnitude_dB = 20 * np.log10(np.abs(h))  # Convert magnitude to dB
    plt.plot(0.5 * sr * w / np.pi, magnitude_dB, 'b')
    plt.title('High-Pass Filter Frequency Response - dB')
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Gain [dB]')
    plt.grid()

    plt.subplot(2, 1, 2)
    plt.plot(0.5 * sr * w / np.pi, np.angle(h), 'b')
    plt.xlabel('Frequency [Hz]')
    plt.ylabel('Phase [radians]')
    plt.grid()

    plt.tight_layout()
    plt.show()

# %%
produce_spectrogram(y_ft, sr_ft, 512, method='stft')
filter_response_plots(y_ft, sr_ft, 512)
# Out:
# Shape of D_filtered: (1025, 862)
# Shape of S_db_filtered: (1025, 862)
# /var/folders/rh/ls0tg20j3l1gps3pmz8g3bkm0000gn/T/ipykernel_49347/3811930545.py:26: RuntimeWarning: divide by zero encountered in log10
#   magnitude_dB = 20 * np.log10(np.abs(h))  # Convert magnitude to dB

# %%
produce_spectrogram(y_ft, sr_ft, 1024, method='stft')
filter_response_plots(y_ft, sr_ft, 1024)
# Out:
# Shape of D_filtered: (1025, 862)
# Shape of S_db_filtered: (1025, 862)
# /var/folders/rh/ls0tg20j3l1gps3pmz8g3bkm0000gn/T/ipykernel_49347/3811930545.py:26: RuntimeWarning: divide by zero encountered in log10
#   magnitude_dB = 20 * np.log10(np.abs(h))  # Convert magnitude to dB
